# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.neighbors import NearestNeighbors

# %%
df = pd.read_csv("../data/songs.csv")

# %%
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0                track_id                 artists  \
# 0             0           0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1             1           1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2             2           2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3             3           3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4             4           4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# ...

# %%
df.shape
# Out:
# (114000, 22)

# %%
df.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'track_id', 'artists', 'album_name',
#        'track_name', 'popularity', 'duration_ms', 'explicit', 'danceability',
#        'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature',
#        'track_genre'],
#       dtype='str')

# %%
df.isnull().sum()
# Out:
# Unnamed: 0.1        0
# Unnamed: 0          0
# track_id            0
# artists             1
# album_name          1
# track_name          1
# popularity          0
# duration_ms         0
# explicit            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# track_genre         0
# dtype: int64

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# Unnamed: 0.1        0
# Unnamed: 0          0
# track_id            0
# artists             0
# album_name          0
# track_name          0
# popularity          0
# duration_ms         0
# explicit            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# track_genre         0
# dtype: int64

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (113999, 22)

# %%
df["track_name"].value_counts().head(10)
# Out:
# track_name
# Run Rudolph Run                   151
# Halloween                          88
# Frosty The Snowman                 81
# Little Saint Nick - 1991 Remix     76
# Last Last                          75
# Christmas Time                     72
# CÓMO SE SIENTE - Remix             64
# Sleigh Ride                        61
# RUMBATÓN                           60
# X ÚLTIMA VEZ                       58
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,5))
df["track_name"].value_counts().head(10).plot(kind="bar")
plt.xlabel("Genre")
plt.ylabel("Number of Songs")
plt.title("Top 10 Music Genres")
plt.xticks(rotation=45)
plt.show()

# %%
df.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'track_id', 'artists', 'album_name',
#        'track_name', 'popularity', 'duration_ms', 'explicit', 'danceability',
#        'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature',
#        'track_genre'],
#       dtype='str')

# %%
features = [
    "danceability",
    "energy",
    "loudness",
    "speechiness",
    "acousticness",
    "instrumentalness",
    "liveness",
    "valence",
    "tempo"
]

# %%
df[features].describe()
# Out:
#         danceability         energy       loudness    speechiness  \
# count  113999.000000  113999.000000  113999.000000  113999.000000
# mean        0.566801       0.641383      -8.258950       0.084652
# std         0.173543       0.251530       5.029357       0.105733
# min         0.000000       0.000000     -49.531000       0.000000
# 25%         0.456000       0.472000     -10.013000       0.035900
# 50%         0.580000       0.685000      -7.004000       0.048900
# 75%         0.695000       0.854000      -5.003000       0.084500
# max         0.985000       1.000000       4.532000       0.965000
#
#         acousticness  instrumentalness       liveness        valence  \
# count  113999.000000     113999.000000  113999.000000  113999.000000
# mean        0.314907          0.156051       0.213554       0.474066
# std         0.332522          0.309556       0.190378       0.259261
# min         0.000000          0.000000       0.000000       0.000000
# ...

# %%
plt.figure(figsize=(10,7))
sns.heatmap(df[features].corr(), annot=True)
plt.title("Music Feature Correlation")
plt.show()

# %%
X = df[features]

# %%
X.head()
# Out:
#    danceability  energy  loudness  speechiness  acousticness  \
# 0         0.676  0.4610    -6.746       0.1430        0.0322
# 1         0.420  0.1660   -17.235       0.0763        0.9240
# 2         0.438  0.3590    -9.734       0.0557        0.2100
# 3         0.266  0.0596   -18.515       0.0363        0.9050
# 4         0.618  0.4430    -9.681       0.0526        0.4690
#
#    instrumentalness  liveness  valence    tempo
# 0          0.000001    0.3580    0.715   87.917
# 1          0.000006    0.1010    0.267   77.489
# 2          0.000000    0.1170    0.120   76.332
# 3          0.000071    0.1320    0.143  181.740
# 4          0.000000    0.0829    0.167  119.949

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
df = df.reset_index(drop=True)

knn = NearestNeighbors(
    n_neighbors=11,
    metric="cosine",
    algorithm="brute"
)

knn.fit(X_scaled) 

def recommend_songs(song_name, num_recommendations=10):
    if song_name not in song_indices:
        return pd.DataFrame()

    idx = song_indices[song_name]

    distances, indices = knn.kneighbors(
        X_scaled[idx:idx+1],
        n_neighbors=num_recommendations + 1
    )

    recommended_indices = indices[0][1:]
    recommended_distances = distances[0][1:]

    result = df.iloc[recommended_indices][
        ["track_name", "artists", "track_genre"]
    ].copy()

    result["similarity"] = 1 - recommended_distances

    return result.reset_index(drop=True)

# %%
song_indices = pd.Series(
    df.index,
    index=df["track_name"]
).to_dict()

# %%
df["track_name"].head(20)
# Out:
# 0                               Comedy
# 1                     Ghost - Acoustic
# 2                       To Begin Again
# 3           Can't Help Falling In Love
# 4                              Hold On
# 5                 Days I Will Remember
# 6                        Say Something
# 7                            I'm Yours
# 8                                Lucky
# 9                               Hunger
# 10                Give Me Your Forever
# 11                     I Won't Give Up
# 12                                Solo
# 13                            Bad Liar
# 14                     Hold On - Remix
# 15    Falling in Love at a Coffee Shop
# 16               ily (i love you baby)
# 17                         At My Worst
# 18                               Lucky
# 19                          Photograph
# Name: track_name, dtype: str

# %%
recommend_songs("Blinding Lights")
# Out:
#         track_name       artists track_genre  similarity
# 0  Blinding Lights  All Time Low   punk-rock         1.0
# 1  Blinding Lights  All Time Low        punk         1.0
# 2  Blinding Lights  All Time Low   punk-rock         1.0
# 3  Blinding Lights  All Time Low   punk-rock         1.0
# 4  Blinding Lights  All Time Low        rock         1.0
# 5  Blinding Lights  All Time Low        rock         1.0
# 6  Blinding Lights  All Time Low        rock         1.0
# 7  Blinding Lights  All Time Low        rock         1.0
# 8  Blinding Lights  All Time Low        punk         1.0
# 9  Blinding Lights  All Time Low        rock         1.0

# %%
df["track_name"].iloc[0]
# Out:
# 'Comedy'

# %%
recommend_songs(df["track_name"].iloc[0])
# Out:
#                            track_name           artists track_genre  \
# 0                              Comedy       Gen Hoshino  songwriter
# 1                              Comedy       Gen Hoshino    acoustic
# 2                              Comedy       Gen Hoshino       j-pop
# 3                            Skylight          Gramatik    trip-hop
# 4                 That Certain Female  Charlie Feathers  rockabilly
# 5  Look For The Good (Single Version)        Jason Mraz    acoustic
# 6                       Monde de fous           Danakil      french
# 7                       Monde de fous           Danakil         dub
# 8                           Blink 182            Trille      german
# 9                           Blink 182            Trille       indie
#
#    similarity
# 0    1.000000
# 1    1.000000
# 2    1.000000
# 3    0.953221
# 4    0.930325
# 5    0.929432
# 6    0.929147
# 7    0.929147
# 8    0.926133
# 9    0.926133

# %%
recommend_songs(df["track_name"].iloc[10])
# Out:
#                    track_name                      artists track_genre  \
# 0        Give Me Your Forever                 Zack Tabudlo    acoustic
# 1                       幸福摩天輪                   Eason Chan    cantopop
# 2  Moonlight, Mistletoe & You     Keb' Mo';Gerald Albright    acoustic
# 3  Moonlight, Mistletoe & You     Keb' Mo';Gerald Albright       blues
# 4                     Used To  Sandro Cavazza;Lou Elliotte     swedish
# 5          You're My Waterloo               The Libertines      garage
# 6              Time for Sleep                  The Wiggles    children
# 7             More Than Words                      Extreme       metal
# 8             More Than Words                      Extreme       metal
# 9             More Than Words                      Extreme        funk
#
#    similarity
# 0    1.000000
# 1    0.978300
# 2    0.974717
# 3    0.974717
# 4    0.962665
# 5    0.961264
# 6    0.959946
# 7    0.959938
# 8    0.959938
# 9    0.959938

# %%
recommend_songs(df["track_name"].iloc[50])
# Out:
#                  track_name                             artists  \
# 0     Trampoline - Acoustic                       Highland Peak
# 1            Dear Theodosia  Leslie Odom Jr.;Lin-Manuel Miranda
# 2                       為什麼                                 盧業瑂
# 3                      Rise                        Boyce Avenue
# 4                  The Bomb              Florence + The Machine
# 5                     River                           Ben Platt
# 6              Settled Down                          Watchhouse
# 7  Please Don't Go Home Yet                     Stephen Sanchez
# 8  Please Don't Go Home Yet                     Stephen Sanchez
# 9                        遺憾                           Abin Fang
#
#          track_genre  similarity
# 0           acoustic    1.000000
# 1         show-tunes    0.997961
# 2           cantopop    0.996993
# 3           acoustic    0.993340
# 4        alternative    0.991878
# 5         show-tunes    0.990979
# ...

# %%
recommend_songs(df["track_name"].iloc[100])
# Out:
#               track_name        artists        track_genre  similarity
# 0                   Rain  Motohiro Hata             j-rock    1.000000
# 1                   Rain  Motohiro Hata              j-pop    1.000000
# 2                   Rain  Motohiro Hata         songwriter    1.000000
# 3                   Rain  Motohiro Hata  singer-songwriter    1.000000
# 4              Nazm Nazm           Arko           pop-film    0.984648
# 5              Nazm Nazm           Arko                pop    0.984648
# 6  The Best Side Of Life   Sarah Connor             german    0.979369
# 7  The Best Side Of Life   Sarah Connor             german    0.979369
# 8  The Best Side Of Life   Sarah Connor             german    0.979369
# 9  The Best Side Of Life   Sarah Connor             german    0.979369

# %%
recommendations = recommend_songs(df["track_name"].iloc[0])

plt.figure(figsize=(10,5))
plt.barh(recommendations["track_name"], recommendations["similarity"])
plt.xlabel("Similarity")
plt.ylabel("Song")
plt.title("Recommended Songs")
plt.gca().invert_yaxis()
plt.show()

# %%
import pickle

# %%
with open("../models/knn.pkl", "wb") as file:
    pickle.dump(knn, file)

# %%
with open("../models/X_scaled.pkl", "wb") as file:
    pickle.dump(X_scaled, file)

# %%
df.to_pickle("../models/songs.pkl")

# %%
song_indices
# Out:
# {'Comedy': 102150,
#  'Ghost - Acoustic': 15190,
#  'To Begin Again': 2,
#  "Can't Help Falling In Love": 92900,
#  'Hold On': 111617,
#  'Days I Will Remember': 56777,
#  'Say Something': 79468,
#  "I'm Yours": 91903,
#  'Lucky': 106084,
#  'Hunger': 79109,
#  'Give Me Your Forever': 462,
#  "I Won't Give Up": 118,
#  'Solo': 103657,
#  'Bad Liar': 91017,
#  'Hold On - Remix': 14,
#  'Falling in Love at a Coffee Shop': 215,
#  'ily (i love you baby)': 53893,
#  'At My Worst': 103223,
#  'Photograph': 81763,
#  'Demons': 94642,
#  '93 Million Miles': 91669,
#  'Unlonely': 91662,
#  'Bella Luna': 91661,
#  'Winter Wonderland': 92112,
#  'If It Kills Me': 91670,
#  'All I Want For Christmas Is A Real Good Tan': 32,
#  'Party of One': 34218,
#  'Lonely This Christmas': 102598,
#  'Throwing Good After Bad': 34221,
#  'This Time Tomorrow': 34235,
#  'The Haves': 40,
#  "When You're Wrong": 34222,
#  'You and Me on the Rock': 34199,
# ...

# %%
with open("../models/song_indices.pkl", "wb") as file:
    pickle.dump(song_indices, file)
